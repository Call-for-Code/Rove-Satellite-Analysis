# %%
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    version='2019-07-22',
    iam_apikey='<redacted>'
)
# Out:
# /Users/maxwu/tools/envs-python/ibm/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
#   """

# %%
import json
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_apikey='<redacted>')

with open('/Users/maxwu/ibm/DamageDetection/Satellite-Analysis/results_2/jpgs.zip', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
	classifier_ids='building-damage_1940922462').get_result()
print(json.dumps(classes, indent=2))
# Out:
# /Users/maxwu/tools/envs-python/ibm/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "building-damage_1940922462",
#           "name": "building-damage",
#           "classes": [
#             {
#               "class": "none_jpgs",
#               "score": 0.871
#             }
#           ]
#         }
#       ],
#       "image": "jpgs.zip/jpgs/DES/img_-95.6766984143841_29.54706298647222.jpg"
#     },
#     {
#       "classifiers": [
#         {
#           "classifier_id": "building-damage_1940922462",
#           "name": "building-damage",
#           "classes": [
#             {
#               "class": "none_jpgs",
#               "score": 0.907
#             }
#           ]
#         }
#       ],
#       "image": "jpgs.zip/jpgs/DES/img_-95.68418388760966_29.545062997821013.jpg"
# ...

# %%
import json
from watson_developer_cloud import VisualRecognitionV3

visual_recognition = VisualRecognitionV3(
    '2018-03-19',
    iam_apikey='<redacted>')

with open('/Users/maxwu/ibm/DamageDetection/Satellite-Analysis/results_2/jpgs.zip', 'rb') as images_file:
    classes = visual_recognition.classify(
        images_file,
        threshold='0.6',
	classifier_ids='building-damage_1940922462').get_result()
print(json.dumps(classes, indent=2))
# Out:
# /Users/maxwu/tools/envs-python/ibm/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: watson-developer-cloud moved to ibm-watson. To get updates, use the new package.
# ---------------------------------------------------------------------------
# WatsonApiException                        Traceback (most recent call last)
# <ipython-input-7-184aba923658> in <module>
#      10         images_file,
#      11         threshold='0.6',
# ---> 12 	classifier_ids='building-damage_1940922462').get_result()
#      13 print(json.dumps(classes, indent=2))
#
# ~/tools/envs-python/ibm/lib/python3.6/site-packages/watson_developer_cloud/visual_recognition_v3.py in classify(self, images_file, accept_language, url, threshold, owners, classifier_ids, images_file_content_type, images_filename, **kwargs)
#     181             params=params,
#     182             files=form_data,
# --> 183             accept_json=True)
#     184         return response
#     185
#
# ...
